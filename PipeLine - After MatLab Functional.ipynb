# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.svm import SVC
from sklearn.utils import resample
import os

# %%
# Llegim el nom dels nodes.
# Obrim el fitxer '.txt' i  llegim les linies.
with open('mindboggle_ROIs_class.txt', 'r') as file:
    header_line = file.readline().strip()

    data = []

    for line in file:
        values = line.strip().split('\t')
        data.append(values)

dict_data = dict()
for i in data:
    node=int(i[0])-1
    dict_data[str(node)] = i[1]
#dict_data

# %% [markdown]
# ### Global Metrics

# %%
# Read CSV File.
file_metrics = 'table_metrics_functional.csv'
#file_metrics = 'table_metrics_structural.csv'
#file_metrics = 'table_metrics_morphological.csv'

df = pd.read_csv(os.path.join('/home/guillem/Downloads/', file_metrics))
df.head()
# Out:
#    Var1  Unnamed_0        id redcap_event_name  controls_ms          dob  \
# 0     0        0.0  002MSVIS       year3_arm_1            1  04-Sep-1963
# 1     1        1.0  003MSVIS       year5_arm_1            1  18-Jan-1959
# 2     2        2.0  004MSVIS       year5_arm_1            1  16-Sep-1956
# 3     3        3.0  005MSVIS       year5_arm_1            1  01-Feb-1978
# 4     4        4.0  010MSVIS       year5_arm_1            1  13-Feb-1964
#
#        msonset      nrldate    age  sex  ...  max_degree   density  \
# 0  10-Jan-1993  16-Mar-2015  51.53  1.0  ...   26.510647  0.246316
# 1  15-Jul-2007  08-Feb-2017  58.06  0.0  ...   27.518505  0.229123
# 2  15-Sep-2010  29-Jun-2017  60.78  1.0  ...   22.584145  0.214035
# 3  01-Aug-2007  13-Jan-2016  37.95  0.0  ...   26.432138  0.265965
# 4  15-Sep-2007  04-Oct-2016  52.64  0.0  ...   25.825618  0.240000
#
#    clustering_coef  assortativity  betw_centr     eglob      eloc  modularity  \
# 0         0.244504       0.133929   28.592105  0.318230  0.335831    1.684211
# 1         0.266561       0.063872   26.039474  0.283577  0.338429    2.315789
# 2         0.322041       0.069352   28.368421  0.303126  0.328440    2.210526
# 3         0.251384       0.115483   95.118421  0.399505  0.346290    2.223684
# 4         0.241344       0.032065   34.750000  0.301244  0.309912    1.881579
#
#    transitivity   strength
# 0      0.014446  12.318171
# 1      0.020698  11.830955
# 2      0.007373  11.378702
# 3      0.025632  13.077351
# 4      0.010379  11.885499
#
# [5 rows x 80 columns]

# %%
print(f"Connexions MS: {np.mean(list(df[df['controls_ms'] == 1]['edges']))}")
print(f"Connexions HV: {np.mean(list(df[df['controls_ms'] == 0]['edges']))}")
# Out:
# Connexions MS: 937.7576559297137
# Connexions HV: 945.6180896935737

# %% [markdown]
# * Implementa la imputació de valors nuls per assegurar-te un bon anàlisi davant les dades incompletes.

# %%
# Imputació de valors null
# Check which columns has null values.
for variable in df.columns:
    if df[variable].isna().any():
        print(f"Column {variable} needs imputation in NULL values.")
# Out:
# Column Unnamed_0 needs imputation in NULL values.
# Column redcap_event_name needs imputation in NULL values.
# Column age needs imputation in NULL values.
# Column sex needs imputation in NULL values.
# Column dd needs imputation in NULL values.
# Column mstype needs imputation in NULL values.
# Column dmd needs imputation in NULL values.
# Column edss needs imputation in NULL values.
# Column uGMSSS needs imputation in NULL values.
# Column oGMSSS needs imputation in NULL values.
# Column sdmt needs imputation in NULL values.
# Column sdmtz needs imputation in NULL values.
# Column pasat needs imputation in NULL values.
# Column zpasat needs imputation in NULL values.
# Column zverbalmemory needs imputation in NULL values.
# Column zvisualmemory needs imputation in NULL values.
# Column zattention needs imputation in NULL values.
# Column zfluency needs imputation in NULL values.
# Column zglobal needs imputation in NULL values.
# Column FA needs imputation in NULL values.
# Column GM needs imputation in NULL values.
# Column RF needs imputation in NULL values.
# Column matrix_functional needs imputation in NULL values.
# Column matrix_structural needs imputation in NULL values.
# Column matrix_morphological needs imputation in NULL values.
# Column num_edges_f needs imputation in NULL values.
# Column mean_degree_f needs imputation in NULL values.
# Column max_degree_f needs imputation in NULL values.
# Column mean_density_f needs imputation in NULL values.
# Column mean_clustering_coefficient_f needs imputation in NULL values.
# Column assortativity_f needs imputation in NULL values.
# Column betweenness_centrality_f needs imputation in NULL values.
# Column global_efficiency_f needs imputation in NULL values.
# Column local_efficiency_f needs imputation in NULL values.
# Column transitivity_f needs imputation in NULL values.
# Column modularity_f needs imputation in NULL values.
# Column num_edges_s needs imputation in NULL values.
# Column mean_degree_s needs imputation in NULL values.
# Column max_degree_s needs imputation in NULL values.
# Column mean_density_s needs imputation in NULL values.
# Column mean_clustering_coefficient_s needs imputation in NULL values.
# Column assortativity_s needs imputation in NULL values.
# Column betweenness_centrality_s needs imputation in NULL values.
# Column global_efficiency_s needs imputation in NULL values.
# Column local_efficiency_s needs imputation in NULL values.
# Column transitivity_s needs imputation in NULL values.
# Column modularity_s needs imputation in NULL values.
# Column num_edges_m needs imputation in NULL values.
# Column mean_degree_m needs imputation in NULL values.
# Column max_degree_m needs imputation in NULL values.
# Column mean_density_m needs imputation in NULL values.
# Column mean_clustering_coefficient_m needs imputation in NULL values.
# Column assortativity_m needs imputation in NULL values.
# Column betweenness_centrality_m needs imputation in NULL values.
# Column global_efficiency_m needs imputation in NULL values.
# Column local_efficiency_m needs imputation in NULL values.
# Column transitivity_m needs imputation in NULL values.
# Column modularity_m needs imputation in NULL values.
# Column matrix needs imputation in NULL values.

# %%
# Summary of all columns
df.describe()
# Out:
#              Var1   Unnamed_0  controls_ms         age         sex  \
# count  265.000000  165.000000   265.000000  165.000000  165.000000
# mean   132.000000   82.000000     0.554717   46.161529    0.278788
# std     76.643112   47.775517     0.497937   10.602227    0.449768
# min      0.000000    0.000000     0.000000   22.660000    0.000000
# 25%     66.000000   41.000000     0.000000   38.210000    0.000000
# 50%    132.000000   82.000000     1.000000   46.330000    0.000000
# 75%    198.000000  123.000000     1.000000   53.840000    1.000000
# max    264.000000  164.000000     1.000000   72.220000    1.000000
#
#                dd      mstype         dmd        edss      uGMSSS  ...  \
# count  165.000000  165.000000  146.000000  165.000000  147.000000  ...
# mean    14.110788    0.060606    2.527397    2.369697    3.031156  ...
# std     10.051942    0.591577    3.167062    1.802689    2.008814  ...
# min     -1.000000   -1.000000    0.000000    0.000000    0.490000  ...
# 25%      7.750000    0.000000    0.000000    1.500000    1.415000  ...
# 50%     12.400000    0.000000    1.000000    2.000000    2.530000  ...
# 75%     19.600000    0.000000    4.750000    3.000000    4.395000  ...
# max     46.130000    2.000000   14.000000    7.500000    9.290000  ...
#
#        max_degree     density  clustering_coef  assortativity  betw_centr  \
# count  265.000000  265.000000       265.000000     265.000000  265.000000
# mean    25.302039    0.256184         0.252956       0.057349   56.929841
# std      2.349938    0.017672         0.045695       0.040903   45.122352
# min     19.812437    0.202456         0.186250      -0.052587    7.789474
# 25%     23.780109    0.250175         0.217079       0.028428   21.500000
# 50%     25.282412    0.258947         0.242262       0.051149   31.578947
# 75%     26.725939    0.264561         0.281866       0.082807   98.092105
# max     33.193278    0.305614         0.414482       0.173790  181.631579
#
#             eglob        eloc  modularity  transitivity    strength
# count  265.000000  265.000000  265.000000    265.000000  265.000000
# mean     0.353201    0.334362    2.367378      0.011140   12.579061
# std      0.049101    0.020999    0.433522      0.009358    0.779402
# min      0.241047    0.275540    1.394737      0.000000    9.799069
# 25%      0.319207    0.319263    1.986842      0.005599   12.273330
# 50%      0.348495    0.333801    2.368421      0.009033   12.571418
# 75%      0.400302    0.347945    2.618421      0.014188   13.036207
# max      0.447488    0.398368    3.592105      0.083466   14.963538
#
# [8 rows x 69 columns]

# %%
# Select the required columns.
columns_x = ['age', 'sex', 'edges', 'degree', 'max_degree', 'density', 'clustering_coef', 'assortativity', 'betw_centr', 'eglob', 'eloc', 'modularity', 'transitivity', 'strength']

# Fill missing values using the mean().
#df.fillna(df.mean(), inplace=True)

X = df[columns_x]
X.head()
# Out:
#      age  sex       edges     degree  max_degree   density  clustering_coef  \
# 0  51.53  1.0  918.383254   9.973684   26.510647  0.246316         0.244504
# 1  58.06  0.0  891.677004   8.907895   27.518505  0.229123         0.266561
# 2  60.78  1.0  839.539014   9.000000   22.584145  0.214035         0.322041
# 3  37.95  0.0  986.034557  10.197368   26.432138  0.265965         0.251384
# 4  52.64  0.0  890.288946   9.500000   25.825618  0.240000         0.241344
#
#    assortativity  betw_centr     eglob      eloc  modularity  transitivity  \
# 0       0.133929   28.592105  0.318230  0.335831    1.684211      0.014446
# 1       0.063872   26.039474  0.283577  0.338429    2.315789      0.020698
# 2       0.069352   28.368421  0.303126  0.328440    2.210526      0.007373
# 3       0.115483   95.118421  0.399505  0.346290    2.223684      0.025632
# 4       0.032065   34.750000  0.301244  0.309912    1.881579      0.010379
#
#     strength
# 0  12.318171
# 1  11.830955
# 2  11.378702
# 3  13.077351
# 4  11.885499

# %%
y = df['controls_ms']
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: controls_ms, dtype: int64

# %%
df_HV = df[df['controls_ms'] == 0]
df_MS = df[df['controls_ms'] == 1]

# %%
from scipy.stats import shapiro, ttest_ind, mannwhitneyu

# Agafem les metriques que es diferencien significativament entre MS i HV per Correcció de Bonferroni.
alpha = 0.05

def check_normality(data, alpha):
    _, p_value = shapiro(data)
    return p_value > alpha

list_significative_metrics = list()
list_bonferroni_correction = dict()
num_matrius = len(df)

for metric in ['edges', 'degree', 'max_degree', 'density', 'clustering_coef', 'assortativity', 'betw_centr', 'eglob', 'modularity','transitivity', 'strength']:
    dades_HV = df[df['controls_ms'] == 0][metric]
    dades_MS = df[df['controls_ms'] == 1][metric]

    normalitat_MS = check_normality(dades_MS, alpha)
    normalitat_HV = check_normality(dades_HV, alpha)
    
    # Es comprova si les dades segueixen una distribució normal.
    if normalitat_MS and normalitat_HV:
        # Si HV i MS segueixen una distribució normal, utilitzem la prova t.
        _, pval = ttest_ind(dades_HV, dades_MS)
        
    # Si no segueixen una distribució normal.
    else:
        # S'utilitza la prova U de Mann-Whitney
        _, pval = mannwhitneyu(dades_HV, dades_MS, alternative='two-sided')
    
    # S'aplica la correció de bonferroni.
    pval_corrected = pval*num_matrius
    
    # Si el pvalue es menor de alpha.
    if pval_corrected <= alpha:
        print(f"Metric: {metric} pvalue: {pval_corrected}")
        list_bonferroni_correction[metric] = pval_corrected   
        list_significative_metrics.append(metric)
# Out:
# Metric: degree pvalue: 4.3612124994859976e-07
# Metric: max_degree pvalue: 1.0619509810598455e-06
# Metric: clustering_coef pvalue: 2.3847078586319976e-10
# Metric: assortativity pvalue: 1.1099811771743618e-08
# Metric: eglob pvalue: 0.011888087187154272

# %%
# Mètriques amb diferències significatives entr eMS i HV.
list(list_bonferroni_correction.keys())
# Out:
# ['degree', 'max_degree', 'clustering_coef', 'assortativity', 'eglob']

# %%
# Constructuct Table (as 'Table 2')
# HEADER: ('MS patients (N = XXX)', 'HV (N = YYY)', 'p value')
# Metrics:  
# 'degree': 0.36 (0.02)  0.34 (0.02)  < 0.001
# etc.

print("Metric  -  MS patients  -  HV volunteers  -  Pvalue")
for metric in list(list_bonferroni_correction.keys()):
    mean_MS_ = np.mean(df_MS[metric])
    std_MS_ = np.std(df_MS[metric])
    
    mean_HV_ = np.mean(df_MS[metric])
    std_HV_ = np.std(df_MS[metric])
    
    print(f'Metric - {metric}: MS: {mean_MS_} ({std_MS_}), HV: {mean_HV_} ({std_HV_}), Pvalue: {list_bonferroni_correction[metric]} \n')
# Out:
# Metric  -  MS patients  -  HV volunteers  -  Pvalue
# Metric - degree: MS: 10.002864303616185 (0.8725956105712799), HV: 10.002864303616185 (0.8725956105712799), Pvalue: 4.3612124994859976e-07
#
# Metric - max_degree: MS: 26.02526763228428 (2.3691205494279606), HV: 26.02526763228428 (2.3691205494279606), Pvalue: 1.0619509810598455e-06
#
# Metric - clustering_coef: MS: 0.26967053487769715 (0.04641075915979285), HV: 0.26967053487769715 (0.04641075915979285), Pvalue: 2.3847078586319976e-10
#
# Metric - assortativity: MS: 0.07164608495112988 (0.04096378974034411), HV: 0.07164608495112988 (0.04096378974034411), Pvalue: 1.1099811771743618e-08
#
# Metric - eglob: MS: 0.343257617261734 (0.05218048664946802), HV: 0.343257617261734 (0.05218048664946802), Pvalue: 0.011888087187154272

# %%
#list_significative_metrics.append('sex')
#list_significative_metrics.append('age')

# Llistat a utilitzar per aplicar models ML.
print(list(list_significative_metrics))
# Out:
# ['degree', 'max_degree', 'clustering_coef', 'assortativity', 'eglob']

# %%
from sklearn.metrics import roc_curve, auc, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Seleccionem les variables significatives.
X_selected_cols = X[list_significative_metrics]

# Dividim les dades en Train i test.
X_train, X_test, y_train, y_test = train_test_split(X_selected_cols, y, test_size=0.2, random_state=42)

print(f"Training set - Features: {X_train.shape}, Labels: {y_train.shape}")
print(f"Testing set - Features: {X_test.shape} Labels: {y_test.shape}")

# RANDOM FOREST CLASSIFIER
# Creem el model de Random Forest Classifier.
model_RFC = RandomForestClassifier(random_state=42)

# Entrenem el model utilitzant dades d'entrenament.
model_RFC.fit(X_train, y_train)

# Duem a terme una predicció amb les dades de Test.
y_pred = model_RFC.predict(X_test)

# Evaluem el model RFC.
accuracy = accuracy_score(y_test, y_pred)
classification_report_result = classification_report(y_test, y_pred)

# Matriu de Confusió.
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot Matriu de confusió.
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Classe 0', 'Classe 1'],
            yticklabels=['Classe 0', 'Classe 1'])
plt.xlabel('Predicció')
plt.ylabel('Real')
plt.title('Matriu de Confusió')
plt.show()

# Show results.
print(f"Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report_result)

# Calculem la curva ROC.
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plot de la curva ROC.
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Obtenim la importancia de cada variable obtinguda pel model RFC.
importancia = model_RFC.feature_importances_

# Ordenem les importàncies i les variables corresponents.
indexes = np.argsort(importancia)[::-1]
feature_names = [list_significative_metrics[i] for i in range(X_selected_cols.shape[1])]

# Plot de la importància de cada variable.
plt.figure(figsize=(10, 6))
plt.bar(range(X_selected_cols.shape[1]), importancia[indexes], align='center')
plt.xticks(range(X_selected_cols.shape[1]), [feature_names[i] for i in indexes], rotation=45)
plt.xlabel('Variables')
plt.ylabel('Importància')
plt.title('Importància de les Variables')
plt.show()
# Out:
# Training set - Features: (212, 5), Labels: (212,)
# Testing set - Features: (53, 5) Labels: (53,)
# Accuracy: 0.81
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.94      0.77        18
#            1       0.96      0.74      0.84        35
#
#     accuracy                           0.81        53
#    macro avg       0.81      0.84      0.81        53
# weighted avg       0.86      0.81      0.82        53

# %% [markdown]
# * **Global: Support Vector Machine**

# %%
from sklearn.metrics import roc_curve, auc, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import SVC

# Seleccionem les variables significatives.
X_selected_cols = X[list_significative_metrics]

y = df['controls_ms']

# Dividim les dades en Train i test.
X_train, X_test, y_train, y_test = train_test_split(X_selected_cols, y, test_size=0.2, random_state=42)

print(f"Training set - Features: {X_train.shape}, Labels: {y_train.shape}")
print(f"Testing set - Features: {X_test.shape} Labels: {y_test.shape}")

# Suppot Vector Machine (SVM).
# Creem el model de Suppor vector Machine.
model_SVM = SVC(kernel='linear')

# Entrenem el model utilitzant dades d'entrenament.
model_SVM.fit(X_train, y_train)

# Duem a terme una predicció amb les dades de Test.
y_pred = model_SVM.predict(X_test)

# Evaluem el model.
accuracy = accuracy_score(y_test, y_pred)
classification_report_result = classification_report(y_test, y_pred)

# Matriu de Confusió.
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot Matriu de confusió.
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Classe 0', 'Classe 1'],
            yticklabels=['Classe 0', 'Classe 1'])
plt.xlabel('Predicció')
plt.ylabel('Real')
plt.title('Matriu de Confusió')
plt.show()

# Show results.
print(f"Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report_result)

# Calculem la curva ROC.
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plot de la curva ROC.
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Obtenim la importancia de cada variable obtinguda pel model.
importancia = np.abs(model_SVM.coef_[0])

# Ordenem les importàncies i les variables corresponents.
indexes = np.argsort(importancia)[::-1]
feature_names = [list_significative_metrics[i] for i in range(X_selected_cols.shape[1])]

# Plot de la importància de cada variable.
plt.figure(figsize=(10, 6))
plt.bar(range(X_selected_cols.shape[1]), importancia[indexes], align='center')
plt.xticks(range(X_selected_cols.shape[1]), [feature_names[i] for i in indexes], rotation=45)
plt.xlabel('Variables')
plt.ylabel('Importància')
plt.title('Importància de les Variables')
plt.show()
# Out:
# Training set - Features: (212, 5), Labels: (212,)
# Testing set - Features: (53, 5) Labels: (53,)
# Accuracy: 0.75
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.67      0.65        18
#            1       0.82      0.80      0.81        35
#
#     accuracy                           0.75        53
#    macro avg       0.73      0.73      0.73        53
# weighted avg       0.76      0.75      0.76        53

# %% [markdown]
# * **Global: KNN**

# %%
from sklearn.metrics import roc_curve, auc, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier

# Seleccionem les variables significatives.
X_selected_cols = X[list_significative_metrics]

y = df['controls_ms']

# Dividim les dades en Train i test.
X_train, X_test, y_train, y_test = train_test_split(X_selected_cols, y, test_size=0.2, random_state=42)

print(f"Training set - Features: {X_train.shape}, Labels: {y_train.shape}")
print(f"Testing set - Features: {X_test.shape} Labels: {y_test.shape}")

# KNN
# Se crea el modelo KNN.
model_KNN = KNeighborsClassifier(n_neighbors=2)

# Entrenem el model utilitzant dades d'entrenament.
model_KNN.fit(X_train, y_train)

# Duem a terme una predicció amb les dades de Test.
y_pred = model_KNN.predict(X_test)

# Evaluem el model KNN.
accuracy = accuracy_score(y_test, y_pred)
classification_report_result = classification_report(y_test, y_pred)

# Matriu de Confusió.
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot Matriu de confusió.
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Classe 0', 'Classe 1'],
            yticklabels=['Classe 0', 'Classe 1'])
plt.xlabel('Predicció')
plt.ylabel('Real')
plt.title('Matriu de Confusió')
plt.show()

# Show results.
print(f"Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report_result)

# Calculem la curva ROC.
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plot de la curva ROC.
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# Training set - Features: (212, 5), Labels: (212,)
# Testing set - Features: (53, 5) Labels: (53,)
# Accuracy: 0.74
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.89      0.70        18
#            1       0.92      0.66      0.77        35
#
#     accuracy                           0.74        53
#    macro avg       0.75      0.77      0.73        53
# weighted avg       0.80      0.74      0.74        53

# %% [markdown]
# * **Global: Logistic Regression**

# %%
from sklearn.metrics import roc_curve, auc, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression

# Seleccionem les variables significatives.
X_selected_cols = df[list_significative_metrics]

y = df['controls_ms']

# Dividim les dades en Train i test.
X_train, X_test, y_train, y_test = train_test_split(X_selected_cols, y, test_size=0.2, random_state=42)

# Logistic Regression
# Se crea el modelo Logistic Regression.
model_LR = LogisticRegression()

# Entrenem el model utilitzant dades d'entrenament.
model_LR.fit(X_train, y_train)

# Duem a terme una predicció amb les dades de Test.
y_pred = model_LR.predict(X_test)

# Evaluem el model Logistic Regression.
accuracy = accuracy_score(y_test, y_pred)
classification_report_result = classification_report(y_test, y_pred)

# Matriu de Confusió.
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot Matriu de confusió.
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Classe 0', 'Classe 1'],
            yticklabels=['Classe 0', 'Classe 1'])
plt.xlabel('Predicció')
plt.ylabel('Real')
plt.title('Matriu de Confusió')
plt.show()

# Show results.
print(f"Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report_result)

# Calculem la curva ROC.
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plot de la curva ROC.
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Obtenim la importancia de cada variable obtinguda pel model.
importancia = np.abs(model_LR.coef_[0])

# Ordenem les importàncies i les variables corresponents.
indexes = np.argsort(importancia)[::-1]
feature_names = [list_significative_metrics[i] for i in range(X_selected_cols.shape[1])]

# Plot de la importància de cada variable.
plt.figure(figsize=(10, 6))
plt.bar(range(X_selected_cols.shape[1]), importancia[indexes], align='center')
plt.xticks(range(X_selected_cols.shape[1]), [feature_names[i] for i in indexes], rotation=45)
plt.xlabel('Variables')
plt.ylabel('Importància')
plt.title('Importància de les Variables')
plt.show()
# Out:
# Accuracy: 0.75
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.67      0.65        18
#            1       0.82      0.80      0.81        35
#
#     accuracy                           0.75        53
#    macro avg       0.73      0.73      0.73        53
# weighted avg       0.76      0.75      0.76        53

# %% [markdown]
# * **Global: Gaussian Naive Bayes**

# %%
from sklearn.metrics import roc_curve, auc, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB

# Seleccionem les variables significatives.
X_selected_cols = df[list_significative_metrics]

y = df['controls_ms']

# Dividim les dades en Train i test.
X_train, X_test, y_train, y_test = train_test_split(X_selected_cols, y, test_size=0.2, random_state=42)

# Gaussian Naive Bayes
# Se crea el modelo Gaussian Naive Bayes.
model_GNB = GaussianNB()

# Entrenem el model utilitzant dades d'entrenament.
model_GNB.fit(X_train, y_train)

# Duem a terme una predicció amb les dades de Test.
y_pred = model_GNB.predict(X_test)

# Evaluem el model Gaussian Naive Bayes.
accuracy = accuracy_score(y_test, y_pred)
classification_report_result = classification_report(y_test, y_pred)

# Matriu de Confusió.
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot Matriu de confusió.
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Classe 0', 'Classe 1'],
            yticklabels=['Classe 0', 'Classe 1'])
plt.xlabel('Predicció')
plt.ylabel('Real')
plt.title('Matriu de Confusió')
plt.show()

# Show results.
print(f"Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report_result)

# Calculem la curva ROC.
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plot de la curva ROC.
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# Accuracy: 0.83
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.89      0.78        18
#            1       0.93      0.80      0.86        35
#
#     accuracy                           0.83        53
#    macro avg       0.81      0.84      0.82        53
# weighted avg       0.85      0.83      0.83        53

# %% [markdown]
# ### Local Metrics

# %%
# Read CSV File.
file_metrics = 'table_metrics_local_functional.csv'
#file_metrics = 'table_metrics_local_structural.csv'
#file_metrics = 'table_metrics_local_morphological.csv'

df_local = pd.read_csv(os.path.join('/home/guillem/Downloads/', file_metrics))
df_local.head()
# Out:
#    Var1  Unnamed_0        id redcap_event_name  controls_ms          dob  \
# 0     0        0.0  002MSVIS       year3_arm_1            1  04-Sep-1963
# 1     1        1.0  003MSVIS       year5_arm_1            1  18-Jan-1959
# 2     2        2.0  004MSVIS       year5_arm_1            1  16-Sep-1956
# 3     3        3.0  005MSVIS       year5_arm_1            1  01-Feb-1978
# 4     4        4.0  010MSVIS       year5_arm_1            1  13-Feb-1964
#
#        msonset      nrldate    age  sex  ...  modularity_66  modularity_67  \
# 0  10-Jan-1993  16-Mar-2015  51.53  1.0  ...              2              2
# 1  15-Jul-2007  08-Feb-2017  58.06  0.0  ...              2              2
# 2  15-Sep-2010  29-Jun-2017  60.78  1.0  ...              1              4
# 3  01-Aug-2007  13-Jan-2016  37.95  0.0  ...              1              2
# 4  15-Sep-2007  04-Oct-2016  52.64  0.0  ...              2              1
#
#    modularity_68  modularity_69  modularity_70  modularity_71  modularity_72  \
# 0              3              2              2              2              1
# 1              3              3              3              2              3
# 2              2              2              2              2              1
# 3              2              1              1              1              1
# 4              2              2              2              2              2
#
#    modularity_73  modularity_74  modularity_75
# 0              2              2              2
# 1              2              3              3
# 2              1              1              1
# 3              1              1              1
# 4              2              2              2
#
# [5 rows x 677 columns]

# %%
# Obtenim el llistat de mètriques locals.
# Get index of 'degree_0'.
index_of_degree0 = df_local.columns.get_loc('degree_0')
list_local_metrics = list(df_local.columns)[index_of_degree0:]

# %%
df_MS_local = df_local[df_local['controls_ms'] == 1]
df_HV_local = df_local[df_local['controls_ms'] == 0]

# %%
from scipy.stats import shapiro, ttest_ind, mannwhitneyu

# Agafem les metriques que es diferencien significativament entre MS i HV per Correcció de Bonferroni.
alpha = 0.05

def check_normality(data, alpha):
    _, p_value = shapiro(data)
    return p_value > alpha

list_significative_metrics_local = list()
list_bonferroni_correction_local = dict()
num_matrius = len(df)

for metric in list_local_metrics:
    dades_HV = df_local[df_local['controls_ms'] == 0][metric]
    dades_MS = df_local[df_local['controls_ms'] == 1][metric]

    normalitat_MS = check_normality(dades_MS, alpha)
    normalitat_HV = check_normality(dades_HV, alpha)
    
    # Es comprova si les dades segueixen una distribució normal.
    if normalitat_MS and normalitat_HV:
        # Si HV i MS segueixen una distribució normal, utilitzem la prova t.
        _, pval = ttest_ind(dades_HV, dades_MS)
        
    # Si no segueixen una distribució normal.
    else:
        # S'utilitza la prova U de Mann-Whitney
        _, pval = mannwhitneyu(dades_HV, dades_MS, alternative='two-sided')
    
    # S'aplica la correció de bonferroni.
    pval_corrected = pval*num_matrius
    
    # Si el pvalue es menor de alpha.
    if pval_corrected <= alpha:
        print(f"Metric: {metric} pvalue: {pval_corrected}")
        list_bonferroni_correction_local[metric] = pval_corrected   
        list_significative_metrics_local.append(metric)
# Out:
# Metric: degree_1 pvalue: 6.944211035827309e-05
# Metric: degree_4 pvalue: 7.955903600009997e-06
# Metric: degree_12 pvalue: 0.0010956036084818733
# Metric: degree_14 pvalue: 0.0007756266522946231
# Metric: degree_17 pvalue: 0.010648265993574118
# Metric: degree_19 pvalue: 0.019645848711149685
# Metric: degree_21 pvalue: 0.017303433492800366
# Metric: degree_22 pvalue: 2.904933756859512e-06
# Metric: degree_23 pvalue: 0.00014499759905383503
# Metric: degree_31 pvalue: 0.0037917621331082984
# Metric: degree_35 pvalue: 1.59509171733354e-05
# Metric: degree_36 pvalue: 1.8133682360130656e-08
# Metric: degree_37 pvalue: 0.00043594977652312893
# Metric: degree_39 pvalue: 0.007880082353271117
# Metric: degree_42 pvalue: 5.676866998382903e-05
# Metric: degree_44 pvalue: 4.271985400724169e-07
# Metric: degree_54 pvalue: 0.037734190016955445
# Metric: degree_58 pvalue: 0.0001459050238234562
# Metric: degree_61 pvalue: 2.801748237562488e-06
# Metric: degree_64 pvalue: 0.00014552343587819963
# Metric: degree_68 pvalue: 6.743738770876257e-11
# Metric: degree_69 pvalue: 0.027485121892064434
# Metric: degree_74 pvalue: 2.7867949215718223e-11
# Metric: degree_75 pvalue: 0.002012032748923263
# Metric: betw_centr_0 pvalue: 2.25315588296949e-05
# Metric: betw_centr_2 pvalue: 0.003272333047022362
# Metric: betw_centr_20 pvalue: 0.007321563640444217
# Metric: betw_centr_21 pvalue: 0.00010842847552330553
# Metric: betw_centr_24 pvalue: 4.1188348932465573e-08
# Metric: betw_centr_26 pvalue: 9.38615152304143e-05
# Metric: betw_centr_31 pvalue: 0.043320112206316076
# Metric: betw_centr_35 pvalue: 0.00012833601946920468
# Metric: betw_centr_36 pvalue: 0.030241359749919716
# Metric: betw_centr_38 pvalue: 3.53128880463377e-05
# Metric: betw_centr_44 pvalue: 1.8142842560665953e-09
# Metric: betw_centr_46 pvalue: 3.3352410657076576e-05
# Metric: betw_centr_47 pvalue: 0.005227230807437372
# Metric: betw_centr_50 pvalue: 0.0035250537633039775
# Metric: betw_centr_55 pvalue: 0.003306280745127556
# Metric: betw_centr_57 pvalue: 0.024791220179551102
# Metric: eigenv_centr_14 pvalue: 0.032068364975892695
# Metric: eigenv_centr_16 pvalue: 0.04348017453877777
# Metric: eigenv_centr_23 pvalue: 0.042233391380259805
# Metric: eigenv_centr_24 pvalue: 0.037489760062934446
# Metric: eigenv_centr_26 pvalue: 0.014508078790789075
# Metric: pager_centr_1 pvalue: 0.0035513247793833034
# Metric: pager_centr_5 pvalue: 1.933348393382066e-08
# Metric: pager_centr_7 pvalue: 0.007586334915435362
# Metric: pager_centr_12 pvalue: 2.5761311555060355e-06
# Metric: pager_centr_14 pvalue: 8.841193794648857e-10
# Metric: pager_centr_15 pvalue: 6.519627242010359e-09
# Metric: pager_centr_16 pvalue: 2.1523374651958854e-08
# Metric: pager_centr_17 pvalue: 8.648657171959863e-07
# Metric: pager_centr_18 pvalue: 0.007640365692048316
# Metric: pager_centr_19 pvalue: 1.185607652740781e-05
# Metric: pager_centr_20 pvalue: 0.01265291733402613
# Metric: pager_centr_21 pvalue: 5.573773671592962e-06
# Metric: pager_centr_23 pvalue: 0.016315371359197216
# Metric: pager_centr_24 pvalue: 1.3858583563149348e-10
# Metric: pager_centr_25 pvalue: 8.670218776844246e-09
# Metric: pager_centr_26 pvalue: 2.542944245244305e-15
# Metric: pager_centr_27 pvalue: 9.44534428916429e-07
# Metric: pager_centr_28 pvalue: 2.4735764939327925e-08
# Metric: pager_centr_33 pvalue: 0.001955331300688631
# Metric: pager_centr_39 pvalue: 0.024791220179551102
# Metric: pager_centr_40 pvalue: 6.275055495694591e-05
# Metric: pager_centr_45 pvalue: 0.0002065293714255888
# Metric: pager_centr_46 pvalue: 8.849137944604872e-06
# Metric: pager_centr_47 pvalue: 7.995705260984055e-07
# Metric: pager_centr_48 pvalue: 0.004172715187877784
# Metric: pager_centr_49 pvalue: 1.3843449600643288e-13
# Metric: pager_centr_50 pvalue: 7.411726951040964e-08
# Metric: pager_centr_51 pvalue: 4.846052988406293e-06
# Metric: pager_centr_52 pvalue: 1.729867267059467e-09
# Metric: pager_centr_53 pvalue: 6.471408684208115e-08
# Metric: pager_centr_54 pvalue: 1.0435165165034718e-05
# Metric: pager_centr_56 pvalue: 0.0011185792757512326
# Metric: pager_centr_57 pvalue: 2.566739066456411e-07
# Metric: pager_centr_61 pvalue: 5.77587100058068e-09
# Metric: pager_centr_62 pvalue: 0.00019011006957628658
# Metric: pager_centr_63 pvalue: 0.0015685701268427436
# Metric: pager_centr_64 pvalue: 0.007804661404539646
# Metric: pager_centr_65 pvalue: 0.00012515445974384476
# Metric: pager_centr_66 pvalue: 0.03956402030134168
# Metric: clust_coef_0 pvalue: 1.3868832737053883e-18
# Metric: clust_coef_1 pvalue: 3.463706552151754e-24
# Metric: clust_coef_2 pvalue: 4.550279778424951e-21
# Metric: clust_coef_3 pvalue: 1.7931684692806637e-08
# Metric: clust_coef_4 pvalue: 3.7129344266717144e-23
# Metric: clust_coef_5 pvalue: 6.289396724216668e-06
# Metric: clust_coef_6 pvalue: 5.435257274488678e-14
# Metric: clust_coef_7 pvalue: 1.8731351300189615e-16
# Metric: clust_coef_8 pvalue: 3.6489088471716824e-24
# Metric: clust_coef_9 pvalue: 2.441617800126356e-18
# /home/guillem/.local/lib/python3.6/site-packages/scipy/stats/morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# Metric: clust_coef_10 pvalue: 3.922168727919321e-15
# Metric: clust_coef_11 pvalue: 2.80492122314205e-12
# Metric: clust_coef_12 pvalue: 3.9483920553204006e-08
# Metric: clust_coef_14 pvalue: 1.0358743706280427e-18
# Metric: clust_coef_15 pvalue: 2.7672518510319646e-16
# Metric: clust_coef_16 pvalue: 2.317877686158609e-13
# Metric: clust_coef_17 pvalue: 3.176875584580536e-13
# Metric: clust_coef_18 pvalue: 4.094066963395067e-17
# Metric: clust_coef_19 pvalue: 1.2954587663059226e-13
# Metric: clust_coef_20 pvalue: 1.6947473929746305e-10
# Metric: clust_coef_21 pvalue: 6.271555277386966e-08
# Metric: clust_coef_22 pvalue: 2.2253443530149883e-14
# Metric: clust_coef_23 pvalue: 4.0986935148779525e-09
# Metric: clust_coef_24 pvalue: 1.5927622468711585e-08
# Metric: clust_coef_25 pvalue: 9.359118518992994e-09
# Metric: clust_coef_26 pvalue: 2.6502017853913396e-10
# Metric: clust_coef_27 pvalue: 9.62869498539544e-05
# Metric: clust_coef_28 pvalue: 0.0003875670953470949
# Metric: clust_coef_32 pvalue: 0.00024156653867539693
# Metric: clust_coef_38 pvalue: 8.476577719744418e-07
# Metric: clust_coef_46 pvalue: 0.0018127417896886108
# Metric: clust_coef_47 pvalue: 1.6357133595158861e-10
# Metric: clust_coef_49 pvalue: 3.2331354961676917e-10
# Metric: clust_coef_50 pvalue: 0.013557377376240725
# Metric: clust_coef_51 pvalue: 2.6193045699024055e-10
# Metric: clust_coef_53 pvalue: 0.0204090317218972
# Metric: clust_coef_54 pvalue: 0.008028927870067325
# Metric: clust_coef_74 pvalue: 0.04853156627074257
# Metric: local_ef_1 pvalue: 8.299049015544998e-09
# Metric: local_ef_2 pvalue: 0.001047236396226487
# Metric: local_ef_8 pvalue: 0.001533190240960474
# Metric: local_ef_9 pvalue: 0.009442232903580774
# Metric: local_ef_14 pvalue: 1.2982759357735147e-10
# Metric: local_ef_15 pvalue: 0.0032624364789015036
# Metric: local_ef_17 pvalue: 0.000455288040632988
# Metric: local_ef_19 pvalue: 1.3367716325361762e-07
# Metric: local_ef_20 pvalue: 0.000350272300460728
# Metric: local_ef_21 pvalue: 0.0068425558118792125
# Metric: local_ef_26 pvalue: 2.3195725898184634e-07
# Metric: local_ef_29 pvalue: 0.017054043819330976
# Metric: local_ef_47 pvalue: 1.7523577683682942e-06
# Metric: local_ef_52 pvalue: 0.0015110360324367942
# Metric: local_ef_53 pvalue: 4.853092724057601e-07
# Metric: local_ef_55 pvalue: 3.4666662257193737e-10
# Metric: local_ef_59 pvalue: 0.008616101620260939
# Metric: local_ef_61 pvalue: 0.002897332108219754
# Metric: local_ef_63 pvalue: 2.384196150836951e-17
# Metric: local_ef_64 pvalue: 0.0005154498071268541
# Metric: local_ef_66 pvalue: 0.01740606911953106
# Metric: local_ef_67 pvalue: 1.1253436058963847e-10
# Metric: local_ef_69 pvalue: 0.006102352315518958
# Metric: local_ef_75 pvalue: 0.03659019249351899
# Metric: strength_0 pvalue: 0.0002868799193613296
# Metric: strength_6 pvalue: 1.2073791367562051e-05
# Metric: strength_8 pvalue: 0.0002048278783775002
# Metric: strength_12 pvalue: 9.631854677299387e-07
# Metric: strength_14 pvalue: 0.003964720007586851
# Metric: strength_17 pvalue: 2.3022212290933087e-05
# Metric: strength_18 pvalue: 4.673140162730875e-05
# Metric: strength_22 pvalue: 0.034985126635826876
# Metric: strength_23 pvalue: 0.0020459682785352712
# Metric: strength_26 pvalue: 0.0201355918690766
# Metric: strength_36 pvalue: 1.128875935906141e-06
# Metric: strength_37 pvalue: 1.2844727175859882e-06
# Metric: strength_42 pvalue: 0.0058511626933537685
# Metric: strength_44 pvalue: 0.002279145265441287
# Metric: strength_54 pvalue: 0.0003875670953470949
# Metric: strength_64 pvalue: 0.000147428701515186
# Metric: strength_66 pvalue: 0.006813415533432706
# Metric: strength_68 pvalue: 5.087113572148532e-09
# Metric: strength_69 pvalue: 0.003910089386562909
# Metric: strength_71 pvalue: 0.009895914954609729
# Metric: strength_72 pvalue: 2.717174797947389e-12
# Metric: strength_73 pvalue: 0.00011641352821566133
# Metric: strength_74 pvalue: 1.088920448974267e-10
# Metric: strength_75 pvalue: 1.3698639938503274e-08

# %%
# Mètriques amb diferències significatives entr eMS i HV.
list(list_bonferroni_correction_local.keys())
# Out:
# ['degree_1',
#  'degree_4',
#  'degree_12',
#  'degree_14',
#  'degree_17',
#  'degree_19',
#  'degree_21',
#  'degree_22',
#  'degree_23',
#  'degree_31',
#  'degree_35',
#  'degree_36',
#  'degree_37',
#  'degree_39',
#  'degree_42',
#  'degree_44',
#  'degree_54',
#  'degree_58',
#  'degree_61',
#  'degree_64',
#  'degree_68',
#  'degree_69',
#  'degree_74',
#  'degree_75',
#  'betw_centr_0',
#  'betw_centr_2',
#  'betw_centr_20',
#  'betw_centr_21',
#  'betw_centr_24',
#  'betw_centr_26',
#  'betw_centr_31',
#  'betw_centr_35',
#  'betw_centr_36',
#  'betw_centr_38',
#  'betw_centr_44',
#  'betw_centr_46',
#  'betw_centr_47',
#  'betw_centr_50',
#  'betw_centr_55',
#  'betw_centr_57',
#  'eigenv_centr_14',
#  'eigenv_centr_16',
#  'eigenv_centr_23',
#  'eigenv_centr_24',
#  'eigenv_centr_26',
#  'pager_centr_1',
#  'pager_centr_5',
#  'pager_centr_7',
#  'pager_centr_12',
#  'pager_centr_14',
#  'pager_centr_15',
#  'pager_centr_16',
#  'pager_centr_17',
#  'pager_centr_18',
#  'pager_centr_19',
#  'pager_centr_20',
#  'pager_centr_21',
#  'pager_centr_23',
#  'pager_centr_24',
#  'pager_centr_25',
#  'pager_centr_26',
#  'pager_centr_27',
#  'pager_centr_28',
#  'pager_centr_33',
#  'pager_centr_39',
#  'pager_centr_40',
#  'pager_centr_45',
#  'pager_centr_46',
#  'pager_centr_47',
#  'pager_centr_48',
#  'pager_centr_49',
#  'pager_centr_50',
#  'pager_centr_51',
#  'pager_centr_52',
#  'pager_centr_53',
#  'pager_centr_54',
#  'pager_centr_56',
#  'pager_centr_57',
#  'pager_centr_61',
#  'pager_centr_62',
#  'pager_centr_63',
#  'pager_centr_64',
#  'pager_centr_65',
#  'pager_centr_66',
#  'clust_coef_0',
#  'clust_coef_1',
#  'clust_coef_2',
#  'clust_coef_3',
#  'clust_coef_4',
#  'clust_coef_5',
#  'clust_coef_6',
#  'clust_coef_7',
#  'clust_coef_8',
#  'clust_coef_9',
#  'clust_coef_10',
#  'clust_coef_11',
#  'clust_coef_12',
#  'clust_coef_14',
#  'clust_coef_15',
#  'clust_coef_16',
#  'clust_coef_17',
#  'clust_coef_18',
#  'clust_coef_19',
#  'clust_coef_20',
#  'clust_coef_21',
#  'clust_coef_22',
#  'clust_coef_23',
#  'clust_coef_24',
#  'clust_coef_25',
#  'clust_coef_26',
#  'clust_coef_27',
#  'clust_coef_28',
#  'clust_coef_32',
#  'clust_coef_38',
#  'clust_coef_46',
#  'clust_coef_47',
#  'clust_coef_49',
#  'clust_coef_50',
#  'clust_coef_51',
#  'clust_coef_53',
#  'clust_coef_54',
#  'clust_coef_74',
#  'local_ef_1',
#  'local_ef_2',
#  'local_ef_8',
#  'local_ef_9',
#  'local_ef_14',
#  'local_ef_15',
#  'local_ef_17',
#  'local_ef_19',
#  'local_ef_20',
#  'local_ef_21',
#  'local_ef_26',
#  'local_ef_29',
#  'local_ef_47',
#  'local_ef_52',
#  'local_ef_53',
#  'local_ef_55',
#  'local_ef_59',
#  'local_ef_61',
#  'local_ef_63',
#  'local_ef_64',
#  'local_ef_66',
#  'local_ef_67',
#  'local_ef_69',
#  'local_ef_75',
#  'strength_0',
#  'strength_6',
#  'strength_8',
#  'strength_12',
#  'strength_14',
#  'strength_17',
#  'strength_18',
#  'strength_22',
#  'strength_23',
#  'strength_26',
#  'strength_36',
#  'strength_37',
#  'strength_42',
#  'strength_44',
#  'strength_54',
#  'strength_64',
#  'strength_66',
#  'strength_68',
#  'strength_69',
#  'strength_71',
#  'strength_72',
#  'strength_73',
#  'strength_74',
#  'strength_75']

# %%
len(list_bonferroni_correction_local)
# Out:
# 170

# %%
# Constructuct Table (as 'Table 2')
# HEADER: ('MS patients (N = XXX)', 'HV (N = YYY)', 'p value')
# Metrics:  
# 'degree': 0.36 (0.02)  0.34 (0.02)  < 0.001
# etc.

print("Metric  -  MS patients  -  HV volunteers  -  Pvalue")
for metric in list(list_bonferroni_correction_local.keys()):
    mean_MS_ = np.mean(df_MS_local[metric])
    std_MS_ = np.std(df_MS_local[metric])
    
    mean_HV_ = np.mean(df_MS_local[metric])
    std_HV_ = np.std(df_MS_local[metric])
    
    print(f'Metric - {metric}: MS: {mean_MS_} ({std_MS_}), HV: {mean_HV_} ({std_HV_}), Pvalue: {list_bonferroni_correction_local[metric]} \n')
# Out:
# Metric  -  MS patients  -  HV volunteers  -  Pvalue
# Metric - degree_1: MS: 1.3265306122448979 (0.8663259296649438), HV: 1.3265306122448979 (0.8663259296649438), Pvalue: 6.944211035827309e-05
#
# Metric - degree_4: MS: 1.7687074829931972 (0.7005151380601905), HV: 1.7687074829931972 (0.7005151380601905), Pvalue: 7.955903600009997e-06
#
# Metric - degree_12: MS: 8.986394557823129 (1.5517661412884656), HV: 8.986394557823129 (1.5517661412884656), Pvalue: 0.0010956036084818733
#
# Metric - degree_14: MS: 6.3061224489795915 (1.5501250548541299), HV: 6.3061224489795915 (1.5501250548541299), Pvalue: 0.0007756266522946231
#
# Metric - degree_17: MS: 6.068027210884353 (1.1288418238199478), HV: 6.068027210884353 (1.1288418238199478), Pvalue: 0.010648265993574118
#
# Metric - degree_19: MS: 9.285714285714286 (2.1852940772540506), HV: 9.285714285714286 (2.1852940772540506), Pvalue: 0.019645848711149685
#
# Metric - degree_21: MS: 11.46938775510204 (2.3395624989259587), HV: 11.46938775510204 (2.3395624989259587), Pvalue: 0.017303433492800366
#
# Metric - degree_22: MS: 10.653061224489797 (2.124214336471715), HV: 10.653061224489797 (2.124214336471715), Pvalue: 2.904933756859512e-06
#
# Metric - degree_23: MS: 6.836734693877551 (1.9132222217371184), HV: 6.836734693877551 (1.9132222217371184), Pvalue: 0.00014499759905383503
#
# Metric - degree_31: MS: 14.748299319727892 (14.984728524214955), HV: 14.748299319727892 (14.984728524214955), Pvalue: 0.0037917621331082984
#
# Metric - degree_35: MS: 14.73469387755102 (12.447072453448282), HV: 14.73469387755102 (12.447072453448282), Pvalue: 1.59509171733354e-05
#
# Metric - degree_36: MS: 6.591836734693878 (2.026206206779571), HV: 6.591836734693878 (2.026206206779571), Pvalue: 1.8133682360130656e-08
#
# Metric - degree_37: MS: 7.727891156462585 (3.0473760836096035), HV: 7.727891156462585 (3.0473760836096035), Pvalue: 0.00043594977652312893
#
# Metric - degree_39: MS: 9.326530612244898 (2.9535249672308663), HV: 9.326530612244898 (2.9535249672308663), Pvalue: 0.007880082353271117
#
# Metric - degree_42: MS: 10.333333333333334 (3.0356909429541385), HV: 10.333333333333334 (3.0356909429541385), Pvalue: 5.676866998382903e-05
#
# Metric - degree_44: MS: 11.462585034013605 (3.0888698786324684), HV: 11.462585034013605 (3.0888698786324684), Pvalue: 4.271985400724169e-07
#
# Metric - degree_54: MS: 16.931972789115648 (4.033296560149862), HV: 16.931972789115648 (4.033296560149862), Pvalue: 0.037734190016955445
#
# Metric - degree_58: MS: 7.040816326530612 (1.9090815935653216), HV: 7.040816326530612 (1.9090815935653216), Pvalue: 0.0001459050238234562
#
# Metric - degree_61: MS: 9.047619047619047 (1.8964102620704644), HV: 9.047619047619047 (1.8964102620704644), Pvalue: 2.801748237562488e-06
#
# Metric - degree_64: MS: 13.122448979591837 (2.7052429799798485), HV: 13.122448979591837 (2.7052429799798485), Pvalue: 0.00014552343587819963
#
# Metric - degree_68: MS: 13.80952380952381 (2.444856695808274), HV: 13.80952380952381 (2.444856695808274), Pvalue: 6.743738770876257e-11
#
# Metric - degree_69: MS: 16.68027210884354 (2.969198784614364), HV: 16.68027210884354 (2.969198784614364), Pvalue: 0.027485121892064434
#
# Metric - degree_74: MS: 12.197278911564625 (2.905868928277872), HV: 12.197278911564625 (2.905868928277872), Pvalue: 2.7867949215718223e-11
#
# Metric - degree_75: MS: 14.97278911564626 (3.428463447171198), HV: 14.97278911564626 (3.428463447171198), Pvalue: 0.002012032748923263
#
# Metric - betw_centr_0: MS: 835.6038838442216 (999.6724045684656), HV: 835.6038838442216 (999.6724045684656), Pvalue: 2.25315588296949e-05
#
# Metric - betw_centr_2: MS: 155.8046903794595 (196.60595856632776), HV: 155.8046903794595 (196.60595856632776), Pvalue: 0.003272333047022362
#
# Metric - betw_centr_20: MS: 15.169996116941189 (21.79629243631176), HV: 15.169996116941189 (21.79629243631176), Pvalue: 0.007321563640444217
#
# Metric - betw_centr_21: MS: 16.13588306392807 (25.59610334351718), HV: 16.13588306392807 (25.59610334351718), Pvalue: 0.00010842847552330553
#
# Metric - betw_centr_24: MS: 14.033833029518503 (24.832500902123417), HV: 14.033833029518503 (24.832500902123417), Pvalue: 4.1188348932465573e-08
#
# Metric - betw_centr_26: MS: 12.23616903811134 (15.357970773097081), HV: 12.23616903811134 (15.357970773097081), Pvalue: 9.38615152304143e-05
#
# Metric - betw_centr_31: MS: 63.83930937548697 (95.51771858391379), HV: 63.83930937548697 (95.51771858391379), Pvalue: 0.043320112206316076
#
# Metric - betw_centr_35: MS: 59.58357468927035 (161.24922207869574), HV: 59.58357468927035 (161.24922207869574), Pvalue: 0.00012833601946920468
#
# Metric - betw_centr_36: MS: 32.201174724873084 (59.864382720987265), HV: 32.201174724873084 (59.864382720987265), Pvalue: 0.030241359749919716
#
# Metric - betw_centr_38: MS: 89.05718701278538 (173.27400138192505), HV: 89.05718701278538 (173.27400138192505), Pvalue: 3.53128880463377e-05
#
# Metric - betw_centr_44: MS: 29.784454764160525 (69.91966394393144), HV: 29.784454764160525 (69.91966394393144), Pvalue: 1.8142842560665953e-09
#
# Metric - betw_centr_46: MS: 3.644221000104707 (6.137165436755055), HV: 3.644221000104707 (6.137165436755055), Pvalue: 3.3352410657076576e-05
#
# Metric - betw_centr_47: MS: 35.00600889774263 (56.8672067123021), HV: 35.00600889774263 (56.8672067123021), Pvalue: 0.005227230807437372
#
# Metric - betw_centr_50: MS: 1.8651948296763428 (2.0052666859376025), HV: 1.8651948296763428 (2.0052666859376025), Pvalue: 0.0035250537633039775
#
# Metric - betw_centr_55: MS: 9.182164495038842 (14.446980104678808), HV: 9.182164495038842 (14.446980104678808), Pvalue: 0.003306280745127556
#
# Metric - betw_centr_57: MS: 24.074405803555237 (29.113618392197804), HV: 24.074405803555237 (29.113618392197804), Pvalue: 0.024791220179551102
#
# Metric - eigenv_centr_14: MS: 0.022679395398325274 (0.01845790082715377), HV: 0.022679395398325274 (0.01845790082715377), Pvalue: 0.032068364975892695
#
# Metric - eigenv_centr_16: MS: 0.02266792446452736 (0.021769446407189492), HV: 0.02266792446452736 (0.021769446407189492), Pvalue: 0.04348017453877777
#
# Metric - eigenv_centr_23: MS: 0.001933139629459938 (0.002990678302030653), HV: 0.001933139629459938 (0.002990678302030653), Pvalue: 0.042233391380259805
#
# Metric - eigenv_centr_24: MS: 0.003748776280410253 (0.005314315591272219), HV: 0.003748776280410253 (0.005314315591272219), Pvalue: 0.037489760062934446
#
# Metric - eigenv_centr_26: MS: 0.002731659524515277 (0.004172271216333864), HV: 0.002731659524515277 (0.004172271216333864), Pvalue: 0.014508078790789075
#
# Metric - pager_centr_1: MS: 0.10596129816883232 (0.03589550347339803), HV: 0.10596129816883232 (0.03589550347339803), Pvalue: 0.0035513247793833034
#
# Metric - pager_centr_5: MS: 0.061665978524680386 (0.05560088286639171), HV: 0.061665978524680386 (0.05560088286639171), Pvalue: 1.933348393382066e-08
#
# Metric - pager_centr_7: MS: 0.029994356137774434 (0.02897138347939162), HV: 0.029994356137774434 (0.02897138347939162), Pvalue: 0.007586334915435362
#
# Metric - pager_centr_12: MS: 0.02633391932025236 (0.0268363226458885), HV: 0.02633391932025236 (0.0268363226458885), Pvalue: 2.5761311555060355e-06
#
# Metric - pager_centr_14: MS: 0.01485022228608091 (0.005609689192697983), HV: 0.01485022228608091 (0.005609689192697983), Pvalue: 8.841193794648857e-10
#
# Metric - pager_centr_15: MS: 0.014900589186137353 (0.005736447833730746), HV: 0.014900589186137353 (0.005736447833730746), Pvalue: 6.519627242010359e-09
#
# Metric - pager_centr_16: MS: 0.01872805874087221 (0.016093137878540168), HV: 0.01872805874087221 (0.016093137878540168), Pvalue: 2.1523374651958854e-08
#
# Metric - pager_centr_17: MS: 0.011380825702751769 (0.0041793346679705684), HV: 0.011380825702751769 (0.0041793346679705684), Pvalue: 8.648657171959863e-07
#
# Metric - pager_centr_18: MS: 0.014156685500168392 (0.016644785400507716), HV: 0.014156685500168392 (0.016644785400507716), Pvalue: 0.007640365692048316
#
# Metric - pager_centr_19: MS: 0.01233614075245033 (0.004001422385571715), HV: 0.01233614075245033 (0.004001422385571715), Pvalue: 1.185607652740781e-05
#
# Metric - pager_centr_20: MS: 0.013855952937956478 (0.013410316224304936), HV: 0.013855952937956478 (0.013410316224304936), Pvalue: 0.01265291733402613
#
# Metric - pager_centr_21: MS: 0.010959602711327513 (0.0033923121643128886), HV: 0.010959602711327513 (0.0033923121643128886), Pvalue: 5.573773671592962e-06
#
# Metric - pager_centr_23: MS: 0.007069847719688862 (0.0021950869741769016), HV: 0.007069847719688862 (0.0021950869741769016), Pvalue: 0.016315371359197216
#
# Metric - pager_centr_24: MS: 0.008970747593970532 (0.002629369060568867), HV: 0.008970747593970532 (0.002629369060568867), Pvalue: 1.3858583563149348e-10
#
# Metric - pager_centr_25: MS: 0.00746179272211033 (0.0024761989874258435), HV: 0.00746179272211033 (0.0024761989874258435), Pvalue: 8.670218776844246e-09
#
# Metric - pager_centr_26: MS: 0.0068608984805485045 (0.0019366485774863994), HV: 0.0068608984805485045 (0.0019366485774863994), Pvalue: 2.542944245244305e-15
#
# Metric - pager_centr_27: MS: 0.00734045413394395 (0.003033920493851476), HV: 0.00734045413394395 (0.003033920493851476), Pvalue: 9.44534428916429e-07
#
# Metric - pager_centr_28: MS: 0.010707752369310826 (0.014164030137964268), HV: 0.010707752369310826 (0.014164030137964268), Pvalue: 2.4735764939327925e-08
#
# Metric - pager_centr_33: MS: 0.0042637118770915165 (0.0014153389237109009), HV: 0.0042637118770915165 (0.0014153389237109009), Pvalue: 0.001955331300688631
#
# Metric - pager_centr_39: MS: 0.004327072068928527 (0.0016386244264350283), HV: 0.004327072068928527 (0.0016386244264350283), Pvalue: 0.024791220179551102
#
# Metric - pager_centr_40: MS: 0.003908650048200426 (0.0016084245292115717), HV: 0.003908650048200426 (0.0016084245292115717), Pvalue: 6.275055495694591e-05
#
# Metric - pager_centr_45: MS: 0.0038937264682553916 (0.002309850944511965), HV: 0.0038937264682553916 (0.002309850944511965), Pvalue: 0.0002065293714255888
#
# Metric - pager_centr_46: MS: 0.005368761935312464 (0.001765591591007275), HV: 0.005368761935312464 (0.001765591591007275), Pvalue: 8.849137944604872e-06
#
# Metric - pager_centr_47: MS: 0.004329509144176287 (0.001233724773706485), HV: 0.004329509144176287 (0.001233724773706485), Pvalue: 7.995705260984055e-07
#
# Metric - pager_centr_48: MS: 0.0028920838589469354 (0.0008088461938764524), HV: 0.0028920838589469354 (0.0008088461938764524), Pvalue: 0.004172715187877784
#
# Metric - pager_centr_49: MS: 0.0036054215910511604 (0.0010104905746058485), HV: 0.0036054215910511604 (0.0010104905746058485), Pvalue: 1.3843449600643288e-13
#
# Metric - pager_centr_50: MS: 0.0044048547586735326 (0.0013576236532826622), HV: 0.0044048547586735326 (0.0013576236532826622), Pvalue: 7.411726951040964e-08
#
# Metric - pager_centr_51: MS: 0.0036292805110288285 (0.001004307089473332), HV: 0.0036292805110288285 (0.001004307089473332), Pvalue: 4.846052988406293e-06
#
# Metric - pager_centr_52: MS: 0.0032335475734952142 (0.0008494282766433025), HV: 0.0032335475734952142 (0.0008494282766433025), Pvalue: 1.729867267059467e-09
#
# Metric - pager_centr_53: MS: 0.0037564213240895506 (0.0011707475351055647), HV: 0.0037564213240895506 (0.0011707475351055647), Pvalue: 6.471408684208115e-08
#
# Metric - pager_centr_54: MS: 0.005290309679931011 (0.005144575305062772), HV: 0.005290309679931011 (0.005144575305062772), Pvalue: 1.0435165165034718e-05
#
# Metric - pager_centr_56: MS: 0.0029084651145266415 (0.0007553363195290111), HV: 0.0029084651145266415 (0.0007553363195290111), Pvalue: 0.0011185792757512326
#
# Metric - pager_centr_57: MS: 0.0035050393860492314 (0.0010493007687539348), HV: 0.0035050393860492314 (0.0010493007687539348), Pvalue: 2.566739066456411e-07
#
# Metric - pager_centr_61: MS: 0.003206025635513528 (0.001353391732691587), HV: 0.003206025635513528 (0.001353391732691587), Pvalue: 5.77587100058068e-09
#
# Metric - pager_centr_62: MS: 0.003881593975887928 (0.001736518341024998), HV: 0.003881593975887928 (0.001736518341024998), Pvalue: 0.00019011006957628658
#
# Metric - pager_centr_63: MS: 0.0026512722392442035 (0.000734720987716964), HV: 0.0026512722392442035 (0.000734720987716964), Pvalue: 0.0015685701268427436
#
# Metric - pager_centr_64: MS: 0.003845165591503199 (0.001762806223282398), HV: 0.003845165591503199 (0.001762806223282398), Pvalue: 0.007804661404539646
#
# Metric - pager_centr_65: MS: 0.0025322853984022487 (0.0006178530446319534), HV: 0.0025322853984022487 (0.0006178530446319534), Pvalue: 0.00012515445974384476
#
# Metric - pager_centr_66: MS: 0.0036758704674519083 (0.0017218060495402029), HV: 0.0036758704674519083 (0.0017218060495402029), Pvalue: 0.03956402030134168
#
# Metric - clust_coef_0: MS: 0.3026261509133093 (0.057840839718004466), HV: 0.3026261509133093 (0.057840839718004466), Pvalue: 1.3868832737053883e-18
#
# Metric - clust_coef_1: MS: 0.3556670765163295 (0.05858988476842736), HV: 0.3556670765163295 (0.05858988476842736), Pvalue: 3.463706552151754e-24
#
# Metric - clust_coef_2: MS: 0.3368461544963328 (0.05070592183126133), HV: 0.3368461544963328 (0.05070592183126133), Pvalue: 4.550279778424951e-21
#
# Metric - clust_coef_3: MS: 0.46563134642268855 (0.19617251319381254), HV: 0.46563134642268855 (0.19617251319381254), Pvalue: 1.7931684692806637e-08
#
# Metric - clust_coef_4: MS: 0.37522684965552794 (0.06223342046136917), HV: 0.37522684965552794 (0.06223342046136917), Pvalue: 3.7129344266717144e-23
#
# Metric - clust_coef_5: MS: 0.3729477601315225 (0.04916969370928965), HV: 0.3729477601315225 (0.04916969370928965), Pvalue: 6.289396724216668e-06
#
# Metric - clust_coef_6: MS: 0.33132074188440014 (0.06918430744723604), HV: 0.33132074188440014 (0.06918430744723604), Pvalue: 5.435257274488678e-14
#
# Metric - clust_coef_7: MS: 0.30074706717184374 (0.05048814253786976), HV: 0.30074706717184374 (0.05048814253786976), Pvalue: 1.8731351300189615e-16
#
# Metric - clust_coef_8: MS: 0.3046135863686106 (0.04818016699584868), HV: 0.3046135863686106 (0.04818016699584868), Pvalue: 3.6489088471716824e-24
#
# Metric - clust_coef_9: MS: 0.27801136596386145 (0.045810162221024166), HV: 0.27801136596386145 (0.045810162221024166), Pvalue: 2.441617800126356e-18
#
# Metric - clust_coef_10: MS: 0.3109462253016308 (0.06787487960920104), HV: 0.3109462253016308 (0.06787487960920104), Pvalue: 3.922168727919321e-15
#
# Metric - clust_coef_11: MS: 0.24682756944339285 (0.05160402220772662), HV: 0.24682756944339285 (0.05160402220772662), Pvalue: 2.80492122314205e-12
#
# Metric - clust_coef_12: MS: 0.21998718815972215 (0.040146121577536255), HV: 0.21998718815972215 (0.040146121577536255), Pvalue: 3.9483920553204006e-08
#
# Metric - clust_coef_14: MS: 0.31722603133471966 (0.04859255549303914), HV: 0.31722603133471966 (0.04859255549303914), Pvalue: 1.0358743706280427e-18
#
# Metric - clust_coef_15: MS: 0.3330945424857091 (0.05655030724260383), HV: 0.3330945424857091 (0.05655030724260383), Pvalue: 2.7672518510319646e-16
#
# Metric - clust_coef_16: MS: 0.2599670919922035 (0.047418704765682336), HV: 0.2599670919922035 (0.047418704765682336), Pvalue: 2.317877686158609e-13
#
# Metric - clust_coef_17: MS: 0.27518815973777266 (0.056139653030358436), HV: 0.27518815973777266 (0.056139653030358436), Pvalue: 3.176875584580536e-13
#
# Metric - clust_coef_18: MS: 0.33490052239837725 (0.08065105166272409), HV: 0.33490052239837725 (0.08065105166272409), Pvalue: 4.094066963395067e-17
#
# Metric - clust_coef_19: MS: 0.24469441075271475 (0.04321961391076934), HV: 0.24469441075271475 (0.04321961391076934), Pvalue: 1.2954587663059226e-13
#
# Metric - clust_coef_20: MS: 0.2667037936063591 (0.04592019601802774), HV: 0.2667037936063591 (0.04592019601802774), Pvalue: 1.6947473929746305e-10
#
# Metric - clust_coef_21: MS: 0.1902855689572768 (0.029800719986854223), HV: 0.1902855689572768 (0.029800719986854223), Pvalue: 6.271555277386966e-08
#
# Metric - clust_coef_22: MS: 0.1984424483250512 (0.04844784125845919), HV: 0.1984424483250512 (0.04844784125845919), Pvalue: 2.2253443530149883e-14
#
# Metric - clust_coef_23: MS: 0.2765768183031482 (0.07577675674351302), HV: 0.2765768183031482 (0.07577675674351302), Pvalue: 4.0986935148779525e-09
#
# Metric - clust_coef_24: MS: 0.22737020715652168 (0.04157168685115998), HV: 0.22737020715652168 (0.04157168685115998), Pvalue: 1.5927622468711585e-08
#
# Metric - clust_coef_25: MS: 0.17388467237503483 (0.06803619483124004), HV: 0.17388467237503483 (0.06803619483124004), Pvalue: 9.359118518992994e-09
#
# Metric - clust_coef_26: MS: 0.20766882788567861 (0.03869890531674294), HV: 0.20766882788567861 (0.03869890531674294), Pvalue: 2.6502017853913396e-10
#
# Metric - clust_coef_27: MS: 0.17946793617852771 (0.048823223726102274), HV: 0.17946793617852771 (0.048823223726102274), Pvalue: 9.62869498539544e-05
#
# Metric - clust_coef_28: MS: 0.22309778900096325 (0.05382087381358656), HV: 0.22309778900096325 (0.05382087381358656), Pvalue: 0.0003875670953470949
#
# Metric - clust_coef_32: MS: 0.36944632551097417 (0.22199465612342922), HV: 0.36944632551097417 (0.22199465612342922), Pvalue: 0.00024156653867539693
#
# Metric - clust_coef_38: MS: 0.316610535097007 (0.14016241235750887), HV: 0.316610535097007 (0.14016241235750887), Pvalue: 8.476577719744418e-07
#
# Metric - clust_coef_46: MS: 0.22988838097960396 (0.057083328528829726), HV: 0.22988838097960396 (0.057083328528829726), Pvalue: 0.0018127417896886108
#
# Metric - clust_coef_47: MS: 0.22278652868958843 (0.0748356681478841), HV: 0.22278652868958843 (0.0748356681478841), Pvalue: 1.6357133595158861e-10
#
# Metric - clust_coef_49: MS: 0.22473076226094 (0.07917374747567181), HV: 0.22473076226094 (0.07917374747567181), Pvalue: 3.2331354961676917e-10
#
# Metric - clust_coef_50: MS: 0.21305048962172962 (0.051823525464929576), HV: 0.21305048962172962 (0.051823525464929576), Pvalue: 0.013557377376240725
# Metric - clust_coef_51: MS: 0.21384515766453946 (0.07652855283928235), HV: 0.21384515766453946 (0.07652855283928235), Pvalue: 2.6193045699024055e-10
#
# Metric - clust_coef_53: MS: 0.19668448434580313 (0.10317948087593377), HV: 0.19668448434580313 (0.10317948087593377), Pvalue: 0.0204090317218972
#
# Metric - clust_coef_54: MS: 0.20017793745544152 (0.08797470211253683), HV: 0.20017793745544152 (0.08797470211253683), Pvalue: 0.008028927870067325
#
# Metric - clust_coef_74: MS: 0.27792506148819235 (0.37543691126588014), HV: 0.27792506148819235 (0.37543691126588014), Pvalue: 0.04853156627074257
#
# Metric - local_ef_1: MS: 0.35267652464179844 (0.03647679709503715), HV: 0.35267652464179844 (0.03647679709503715), Pvalue: 8.299049015544998e-09
#
# Metric - local_ef_2: MS: 0.3430378043145486 (0.0262493993155356), HV: 0.3430378043145486 (0.0262493993155356), Pvalue: 0.001047236396226487
#
# Metric - local_ef_8: MS: 0.352536354035894 (0.03197677540460764), HV: 0.352536354035894 (0.03197677540460764), Pvalue: 0.001533190240960474
#
# Metric - local_ef_9: MS: 0.33987842878145236 (0.038527986963944404), HV: 0.33987842878145236 (0.038527986963944404), Pvalue: 0.009442232903580774
#
# Metric - local_ef_14: MS: 0.357806616683794 (0.031616328731257005), HV: 0.357806616683794 (0.031616328731257005), Pvalue: 1.2982759357735147e-10
#
# Metric - local_ef_15: MS: 0.38118560053760064 (0.062088787661340274), HV: 0.38118560053760064 (0.062088787661340274), Pvalue: 0.0032624364789015036
#
# Metric - local_ef_17: MS: 0.33573212007782366 (0.032287000652875895), HV: 0.33573212007782366 (0.032287000652875895), Pvalue: 0.000455288040632988
#
# Metric - local_ef_19: MS: 0.32658218275790174 (0.03198846909714457), HV: 0.32658218275790174 (0.03198846909714457), Pvalue: 1.3367716325361762e-07
#
# Metric - local_ef_20: MS: 0.35007172452180574 (0.03794226627560711), HV: 0.35007172452180574 (0.03794226627560711), Pvalue: 0.000350272300460728
#
# Metric - local_ef_21: MS: 0.3274605233911225 (0.03364646359953486), HV: 0.3274605233911225 (0.03364646359953486), Pvalue: 0.0068425558118792125
#
# Metric - local_ef_26: MS: 0.3460517149380959 (0.02863713728195053), HV: 0.3460517149380959 (0.02863713728195053), Pvalue: 2.3195725898184634e-07
#
# Metric - local_ef_29: MS: 0.30645885523190397 (0.05120846429347203), HV: 0.30645885523190397 (0.05120846429347203), Pvalue: 0.017054043819330976
#
# Metric - local_ef_47: MS: 0.34884248914282656 (0.03349701408702702), HV: 0.34884248914282656 (0.03349701408702702), Pvalue: 1.7523577683682942e-06
#
# Metric - local_ef_52: MS: 0.3506707789866133 (0.02891799542541085), HV: 0.3506707789866133 (0.02891799542541085), Pvalue: 0.0015110360324367942
#
# Metric - local_ef_53: MS: 0.35924714208447384 (0.03360657704275928), HV: 0.35924714208447384 (0.03360657704275928), Pvalue: 4.853092724057601e-07
#
# Metric - local_ef_55: MS: 0.38435456076454005 (0.03737629128011612), HV: 0.38435456076454005 (0.03737629128011612), Pvalue: 3.4666662257193737e-10
#
# Metric - local_ef_59: MS: 0.3986470985629104 (0.037042368362494735), HV: 0.3986470985629104 (0.037042368362494735), Pvalue: 0.008616101620260939
#
# Metric - local_ef_61: MS: 0.37695174242773544 (0.03612509351362292), HV: 0.37695174242773544 (0.03612509351362292), Pvalue: 0.002897332108219754
#
# Metric - local_ef_63: MS: 0.390782435118811 (0.030164868810108648), HV: 0.390782435118811 (0.030164868810108648), Pvalue: 2.384196150836951e-17
#
# Metric - local_ef_64: MS: 0.3817345515522006 (0.045583460136928995), HV: 0.3817345515522006 (0.045583460136928995), Pvalue: 0.0005154498071268541
#
# Metric - local_ef_66: MS: 0.3713842767335754 (0.04849413333569581), HV: 0.3713842767335754 (0.04849413333569581), Pvalue: 0.01740606911953106
#
# Metric - local_ef_67: MS: 0.36543169932149094 (0.04017720043404989), HV: 0.36543169932149094 (0.04017720043404989), Pvalue: 1.1253436058963847e-10
#
# Metric - local_ef_69: MS: 0.3899256783836198 (0.05391131881978217), HV: 0.3899256783836198 (0.05391131881978217), Pvalue: 0.006102352315518958
#
# Metric - local_ef_75: MS: 0.38996033996894713 (0.08021715325512149), HV: 0.38996033996894713 (0.08021715325512149), Pvalue: 0.03659019249351899
#
# Metric - strength_0: MS: 1.5829423843224384 (1.0751321335554995), HV: 1.5829423843224384 (1.0751321335554995), Pvalue: 0.0002868799193613296
#
# Metric - strength_6: MS: 10.440875826595196 (3.3816819019248463), HV: 10.440875826595196 (3.3816819019248463), Pvalue: 1.2073791367562051e-05
#
# Metric - strength_8: MS: 8.744153003056315 (2.467195310636654), HV: 8.744153003056315 (2.467195310636654), Pvalue: 0.0002048278783775002
#
# Metric - strength_12: MS: 19.98837196916347 (3.1646525285707168), HV: 19.98837196916347 (3.1646525285707168), Pvalue: 9.631854677299387e-07
#
# Metric - strength_14: MS: 13.190542752628362 (3.9618487782313805), HV: 13.190542752628362 (3.9618487782313805), Pvalue: 0.003964720007586851
#
# Metric - strength_17: MS: 13.479003218682212 (3.01980035359197), HV: 13.479003218682212 (3.01980035359197), Pvalue: 2.3022212290933087e-05
#
# Metric - strength_18: MS: 14.90399569075785 (3.2890902583502593), HV: 14.90399569075785 (3.2890902583502593), Pvalue: 4.673140162730875e-05
#
# Metric - strength_22: MS: 17.877539908314372 (3.4419869871470246), HV: 17.877539908314372 (3.4419869871470246), Pvalue: 0.034985126635826876
#
# Metric - strength_23: MS: 11.38427608211604 (3.251724604910744), HV: 11.38427608211604 (3.251724604910744), Pvalue: 0.0020459682785352712
#
# Metric - strength_26: MS: 21.87432355817556 (3.5959352222544507), HV: 21.87432355817556 (3.5959352222544507), Pvalue: 0.0201355918690766
#
# Metric - strength_36: MS: 8.822186452580564 (3.445136094215367), HV: 8.822186452580564 (3.445136094215367), Pvalue: 1.128875935906141e-06
#
# Metric - strength_37: MS: 8.96277322636748 (3.8987022100964506), HV: 8.96277322636748 (3.8987022100964506), Pvalue: 1.2844727175859882e-06
#
# Metric - strength_42: MS: 11.896071106230224 (3.6527663992403157), HV: 11.896071106230224 (3.6527663992403157), Pvalue: 0.0058511626933537685
#
# Metric - strength_44: MS: 12.989757606062344 (3.2895850812269294), HV: 12.989757606062344 (3.2895850812269294), Pvalue: 0.002279145265441287
#
# Metric - strength_54: MS: 16.1617657903773 (3.390109131581424), HV: 16.1617657903773 (3.390109131581424), Pvalue: 0.0003875670953470949
#
# Metric - strength_64: MS: 12.394313381922045 (2.72115792051402), HV: 12.394313381922045 (2.72115792051402), Pvalue: 0.000147428701515186
#
# Metric - strength_66: MS: 15.856054507552598 (2.939095055795454), HV: 15.856054507552598 (2.939095055795454), Pvalue: 0.006813415533432706
#
# Metric - strength_68: MS: 13.048283013606882 (3.690551045902196), HV: 13.048283013606882 (3.690551045902196), Pvalue: 5.087113572148532e-09
#
# Metric - strength_69: MS: 15.015822026568971 (3.459517960789742), HV: 15.015822026568971 (3.459517960789742), Pvalue: 0.003910089386562909
#
# Metric - strength_71: MS: 15.207920755157966 (3.0374520001135843), HV: 15.207920755157966 (3.0374520001135843), Pvalue: 0.009895914954609729
#
# Metric - strength_72: MS: 9.749375326863863 (2.3278857364266554), HV: 9.749375326863863 (2.3278857364266554), Pvalue: 2.717174797947389e-12
#
# Metric - strength_73: MS: 16.531378143562844 (3.6025558939584994), HV: 16.531378143562844 (3.6025558939584994), Pvalue: 0.00011641352821566133
#
# Metric - strength_74: MS: 10.54998048315819 (3.1446728499759535), HV: 10.54998048315819 (3.1446728499759535), Pvalue: 1.088920448974267e-10
#
# Metric - strength_75: MS: 12.86763918016342 (4.016040448078623), HV: 12.86763918016342 (4.016040448078623), Pvalue: 1.3698639938503274e-08

# %% [markdown]
# * **Local: Random Forest Classifier**

# %%
from sklearn.metrics import roc_curve, auc, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Seleccionem les variables significatives.
X_selected_cols = df_local[list_significative_metrics_local]

y = df['controls_ms']

# Dividim les dades en Train i test.
X_train, X_test, y_train, y_test = train_test_split(X_selected_cols, y, test_size=0.2, random_state=42)

print(f"Training set - Features: {X_train.shape}, Labels: {y_train.shape}")
print(f"Testing set - Features: {X_test.shape} Labels: {y_test.shape}")

# RANDOM FOREST CLASSIFIER
# Creem el model de Random Forest Classifier.
model_RFC = RandomForestClassifier(random_state=42)

# Entrenem el model utilitzant dades d'entrenament.
model_RFC.fit(X_train, y_train)

# Duem a terme una predicció amb les dades de Test.
y_pred = model_RFC.predict(X_test)

# Evaluem el model RFC.
accuracy = accuracy_score(y_test, y_pred)
classification_report_result = classification_report(y_test, y_pred)

# Matriu de Confusió.
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot Matriu de confusió.
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Classe 0', 'Classe 1'],
            yticklabels=['Classe 0', 'Classe 1'])
plt.xlabel('Predicció')
plt.ylabel('Real')
plt.title('Matriu de Confusió')
plt.show()

# Show results.
print(f"Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report_result)

# Calculem la curva ROC.
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plot de la curva ROC.
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Obtenim la importancia de cada variable obtinguda pel model RFC.
importancia = model_RFC.feature_importances_

# Ordenem les importàncies i les variables corresponents.
indexes = np.argsort(importancia)[::-1]
feature_names = [list_significative_metrics_local[i] for i in range(X_selected_cols.shape[1])]

# Plot de la importància de cada variable.
plt.figure(figsize=(10, 6))
plt.bar(range(X_selected_cols.shape[1]), importancia[indexes], align='center')
plt.xticks(range(X_selected_cols.shape[1]), [feature_names[i] for i in indexes], rotation=45)
plt.xlabel('Variables')
plt.ylabel('Importància')
plt.title('Importància de les Variables')
plt.show()
# Out:
# Training set - Features: (212, 170), Labels: (212,)
# Testing set - Features: (53, 170) Labels: (53,)
# Accuracy: 0.96
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94        18
#            1       0.97      0.97      0.97        35
#
#     accuracy                           0.96        53
#    macro avg       0.96      0.96      0.96        53
# weighted avg       0.96      0.96      0.96        53

# %% [markdown]
# * **Local: Support Vector Machine (SVM)**

# %%
from sklearn.metrics import roc_curve, auc, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import SVC

# Seleccionem les variables significatives.
X_selected_cols = df_local[list_significative_metrics_local]

y = df['controls_ms']

# Dividim les dades en Train i test.
X_train, X_test, y_train, y_test = train_test_split(X_selected_cols, y, test_size=0.2, random_state=42)

print(f"Training set - Features: {X_train.shape}, Labels: {y_train.shape}")
print(f"Testing set - Features: {X_test.shape} Labels: {y_test.shape}")

# Suppot Vector Machine (SVM).
# Creem el model de Suppor vector Machine.
model_SVM = SVC(kernel='linear')

# Entrenem el model utilitzant dades d'entrenament.
model_SVM.fit(X_train, y_train)

# Duem a terme una predicció amb les dades de Test.
y_pred = model_SVM.predict(X_test)

# Evaluem el model.
accuracy = accuracy_score(y_test, y_pred)
classification_report_result = classification_report(y_test, y_pred)

# Matriu de Confusió.
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot Matriu de confusió.
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Classe 0', 'Classe 1'],
            yticklabels=['Classe 0', 'Classe 1'])
plt.xlabel('Predicció')
plt.ylabel('Real')
plt.title('Matriu de Confusió')
plt.show()

# Show results.
print(f"Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report_result)

# Calculem la curva ROC.
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plot de la curva ROC.
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Obtenim la importancia de cada variable obtinguda pel model.
importancia = np.abs(model_SVM.coef_[0])

# Ordenem les importàncies i les variables corresponents.
indexes = np.argsort(importancia)[::-1]
feature_names = [list_significative_metrics_local[i] for i in range(X_selected_cols.shape[1])]

# Plot de la importància de cada variable.
plt.figure(figsize=(10, 6))
plt.bar(range(X_selected_cols.shape[1]), importancia[indexes], align='center')
plt.xticks(range(X_selected_cols.shape[1]), [feature_names[i] for i in indexes], rotation=45)
plt.xlabel('Variables')
plt.ylabel('Importància')
plt.title('Importància de les Variables')
plt.show()
# Out:
# Training set - Features: (212, 170), Labels: (212,)
# Testing set - Features: (53, 170) Labels: (53,)
# Accuracy: 0.91
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87        18
#            1       0.97      0.89      0.93        35
#
#     accuracy                           0.91        53
#    macro avg       0.89      0.92      0.90        53
# weighted avg       0.91      0.91      0.91        53

# %% [markdown]
# * **Local: KNN**

# %%
from sklearn.metrics import roc_curve, auc, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier

# Seleccionem les variables significatives.
X_selected_cols = df_local[list_significative_metrics_local]

y = df['controls_ms']

# Dividim les dades en Train i test.
X_train, X_test, y_train, y_test = train_test_split(X_selected_cols, y, test_size=0.2, random_state=42)

print(f"Training set - Features: {X_train.shape}, Labels: {y_train.shape}")
print(f"Testing set - Features: {X_test.shape} Labels: {y_test.shape}")

# KNN
# Se crea el modelo KNN.
model_KNN = KNeighborsClassifier(n_neighbors=2)

# Entrenem el model utilitzant dades d'entrenament.
model_KNN.fit(X_train, y_train)

# Duem a terme una predicció amb les dades de Test.
y_pred = model_KNN.predict(X_test)

# Evaluem el model KNN.
accuracy = accuracy_score(y_test, y_pred)
classification_report_result = classification_report(y_test, y_pred)

# Matriu de Confusió.
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot Matriu de confusió.
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Classe 0', 'Classe 1'],
            yticklabels=['Classe 0', 'Classe 1'])
plt.xlabel('Predicció')
plt.ylabel('Real')
plt.title('Matriu de Confusió')
plt.show()

# Show results.
print(f"Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report_result)

# Calculem la curva ROC.
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plot de la curva ROC.
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# Training set - Features: (212, 170), Labels: (212,)
# Testing set - Features: (53, 170) Labels: (53,)
# Accuracy: 0.66
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.89      0.64        18
#            1       0.90      0.54      0.68        35
#
#     accuracy                           0.66        53
#    macro avg       0.70      0.72      0.66        53
# weighted avg       0.77      0.66      0.67        53

# %% [markdown]
# * **Local: Logistic regression**

# %%
from sklearn.metrics import roc_curve, auc, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression

# Seleccionem les variables significatives.
X_selected_cols = df_local[list_significative_metrics_local]

y = df['controls_ms']

# Dividim les dades en Train i test.
X_train, X_test, y_train, y_test = train_test_split(X_selected_cols, y, test_size=0.2, random_state=42)

# Logistic Regression
# Se crea el modelo Logistic Regression.
model_LR = LogisticRegression()

# Entrenem el model utilitzant dades d'entrenament.
model_LR.fit(X_train, y_train)

# Duem a terme una predicció amb les dades de Test.
y_pred = model_LR.predict(X_test)

# Evaluem el model Logistic Regression.
accuracy = accuracy_score(y_test, y_pred)
classification_report_result = classification_report(y_test, y_pred)

# Matriu de Confusió.
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot Matriu de confusió.
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Classe 0', 'Classe 1'],
            yticklabels=['Classe 0', 'Classe 1'])
plt.xlabel('Predicció')
plt.ylabel('Real')
plt.title('Matriu de Confusió')
plt.show()

# Show results.
print(f"Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report_result)

# Calculem la curva ROC.
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plot de la curva ROC.
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Obtenim la importancia de cada variable obtinguda pel model.
importancia = np.abs(model_LR.coef_[0])

# Ordenem les importàncies i les variables corresponents.
indexes = np.argsort(importancia)[::-1]
feature_names = [list_significative_metrics_local[i] for i in range(X_selected_cols.shape[1])]

# Plot de la importància de cada variable.
plt.figure(figsize=(10, 6))
plt.bar(range(X_selected_cols.shape[1]), importancia[indexes], align='center')
plt.xticks(range(X_selected_cols.shape[1]), [feature_names[i] for i in indexes], rotation=45)
plt.xlabel('Variables')
plt.ylabel('Importància')
plt.title('Importància de les Variables')
plt.show()
# Out:
# /home/guillem/.local/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Accuracy: 0.91
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87        18
#            1       0.97      0.89      0.93        35
#
#     accuracy                           0.91        53
#    macro avg       0.89      0.92      0.90        53
# weighted avg       0.91      0.91      0.91        53

# %% [markdown]
# * **Local: Gaussian Naive Bayes (GNB)**

# %%
from sklearn.metrics import roc_curve, auc, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB

# Seleccionem les variables significatives.
X_selected_cols = df_local[list_significative_metrics_local]

y = df['controls_ms']

# Dividim les dades en Train i test.
X_train, X_test, y_train, y_test = train_test_split(X_selected_cols, y, test_size=0.2, random_state=42)

# Gaussian Naive Bayes
# Se crea el modelo Gaussian Naive Bayes.
model_GNB = GaussianNB()

# Entrenem el model utilitzant dades d'entrenament.
model_GNB.fit(X_train, y_train)

# Duem a terme una predicció amb les dades de Test.
y_pred = model_GNB.predict(X_test)

# Evaluem el model Gaussian Naive Bayes.
accuracy = accuracy_score(y_test, y_pred)
classification_report_result = classification_report(y_test, y_pred)

# Matriu de Confusió.
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot Matriu de confusió.
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Classe 0', 'Classe 1'],
            yticklabels=['Classe 0', 'Classe 1'])
plt.xlabel('Predicció')
plt.ylabel('Real')
plt.title('Matriu de Confusió')
plt.show()

# Show results.
print(f"Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report_result)

# Calculem la curva ROC.
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plot de la curva ROC.
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# Accuracy: 0.98
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        18
#            1       0.97      1.00      0.99        35
#
#     accuracy                           0.98        53
#    macro avg       0.99      0.97      0.98        53
# weighted avg       0.98      0.98      0.98        53

# %% [markdown]
# * Clinical and demographic characteristics of the subjects included in the study.

# %%
# Construct Table 1 (Clinic and demographic characteristics of the subjects).

demographic_features_variables = ['sex', 'age']
demographic_features_variables_dict = dict()

for var in demographic_features_variables:
    dades_HV = df_HV[var]
    dades_MS = df_MS[var]

    normalitat_HV = check_normality(dades_HV, 0.05)
    normalitat_MS = check_normality(dades_MS, 0.05)
    
    if normalitat_HV and normalitat_MS:
        _, pvalue_t = ttest_ind(dades_HV, dades_MS)
        #print("pvalue_t:", pvalue_t)
        demographic_features_variables_dict[var] = pvalue_t
    
    # Prova mostres independents.
    else:
        _, pvalue_u = mannwhitneyu(dades_HV, dades_MS, alternative='two-sided')
        #print("pvalue_u:", pvalue_u)
        demographic_features_variables_dict[var] = pvalue_u

# %%
# RRMS: 0, SPMS: 1, PPMS (2)
RRMS = df_MS[df_MS['mstype'] == 0].count()['mstype']
SPMS = df_MS[df_MS['mstype'] == 1].count()['mstype']
PPMS = df_MS[df_MS['mstype'] == 2].count()['mstype']

perc_RRMS = RRMS/len(list(df_MS['mstype']))
perc_SPMS = SPMS/len(list(df_MS['mstype']))
perc_PPMS = PPMS/len(list(df_MS['mstype']))

# %%
# Obtenim la mitjana de volum de tots els nodes Controls.
# Llegir excel.
volum_df_HV = pd.read_excel('VOLUM_NODES_CONTROLS.xls')

# Calculem la mitjana de tots els nodes.
column_avg_HV = volum_df_HV.mean()
avg_volum_HV = column_avg_HV.mean()
std_volum_HV = column_avg_HV.std()


# Obtenim la mitjana de volum de tots els nodes MS.
# Llegir excel.
volum_df_MS = pd.read_excel('VOLUM_NODES_PATIENTS.xls')

# Calculem la mitjana de tots els nodes.
column_avg_MS = volum_df_MS.mean()
avg_volum_MS = column_avg_MS.mean()
std_volum_MS = column_avg_MS.std()

# Comprovem la normalitat i calculem el pvalue.
dades_HV = column_avg_HV
dades_MS = column_avg_MS

normalitat_HV = check_normality(dades_HV, 0.05)
normalitat_MS = check_normality(dades_MS, 0.05)

if normalitat_HV and normalitat_MS:
    _, pvalue_volum = ttest_ind(dades_HV, dades_MS)
    print("pvalue_t:", pvalue_volum)

# Prova mostres independents.
else:
    _, pvalue_volum = mannwhitneyu(dades_HV, dades_MS, alternative='two-sided')
    print("pvalue_u:", pvalue_volum)
# Out:
# pvalue_u: 0.4622499461255427

# %%
print("          'MS patients'     'HV volunteers'    'Pvalue'\n")
print(f"Female (N, %): {(df_MS['sex'] == 0).sum()} ({(df_MS['sex'] == 0).sum()/len(list(df_MS['sex']))}), {(df_HV['sex'] == 0).sum()} ({(df_HV['sex'] == 0).sum()/len(list(df_HV['sex']))}) pvalue: {demographic_features_variables_dict['sex']}")
print(f"Age (years): {np.mean(df_MS['age'])} ({np.std(df_MS['age'])}), {np.mean(df_HV['age'])} ({np.std(df_HV['age'])}), pvalue: {demographic_features_variables_dict['age']}\n")
print("Type of MS:")
print(f"RRMS: {RRMS} ({perc_RRMS})  na  na")
print(f"SPMS: {SPMS} ({perc_SPMS})  na  na")
print(f"PPMS: {PPMS} ({perc_PPMS})  na  na\n")
print(f"Avg Node volum: {avg_volum_MS}, {avg_volum_HV}, p_value: {pvalue_volum}")
print(f"Disease Duration: {np.mean(df_MS['dd'])} ({np.std(df_MS['dd'])}),   na   na  ")
print(f"EDSS Score (gravetat): {np.mean(df_MS['edss'])} ({np.std(df_MS['edss'])}),   na   na  ")
print(f"zSDMT: {np.mean(df_MS['sdmtz'])} ({np.std(df_MS['sdmtz'])}),   na   na  ")
print(f"zPASAT: {np.mean(df_MS['zpasat'])} ({np.std(df_MS['zpasat'])}),   na   na  ")
print(f"zAttention: {np.mean(df_MS['zattention'])} ({np.std(df_MS['zattention'])}),   na   na  ")
# Out:
#           'MS patients'     'HV volunteers'    'Pvalue'
#
# Female (N, %): 104 (0.7074829931972789), 99 (0.8389830508474576) pvalue: 0.01216832937605819
# Age (years): 47.33013605442177 (10.110612797350703), 36.61790630466201 (3.6448028929959047), pvalue: 8.388594573473506e-24
#
# Type of MS:
# RRMS: 125 (0.8503401360544217)  na  na
# SPMS: 16 (0.10884353741496598)  na  na
# PPMS: 6 (0.04081632653061224)  na  na
#
# Avg Node volum: 8635.448684210527, 9328.701754385966, p_value: 0.4622499461255427
# Disease Duration: 15.961088435374148 (9.01906326713972),   na   na
# EDSS Score (gravetat): 2.6598639455782314 (1.6892883766794917),   na   na
# zSDMT: 0.07902865573770491 (1.0603561342433823),   na   na
# zPASAT: -0.2892552 (1.3281360383373986),   na   na
# zAttention: -0.2857193548387097 (1.0301272962112904),   na   na

# %% [markdown]
# ### Visualització en 3D cerebral amb representació dels nodes

# %%
# Llegim el fitxer.
df_nodes_coordinates = pd.read_table('Node_mindboggle_default.node', header = None)
df_nodes_coordinates.rename(columns={0: "x", 1: "y", 2: "z", 5: "node_name"}, inplace = True)
df_nodes_coordinates.head()
# Out:
#        x      y     z  3  4                       node_name
# 0  -4.28  16.90  28.3  2  1  ctx-lh-caudalanteriorcingulate
# 1 -35.20  12.00  46.5  3  1      ctx-lh-caudalmiddlefrontal
# 2  -6.44 -87.50  25.5  4  1                   ctx-lh-cuneus
# 3 -22.20  -4.61 -35.8  5  1               ctx-lh-entorhinal
# 4 -33.30 -41.70 -21.6  6  1                 ctx-lh-fusiform

# %%
# Create an example adjacency matrix (replace this with your own matrix)
matrix = pd.read_csv(
    os.path.join(
        os.getcwd(), 'subject_networks_rfMRI_v1', '002MSVIS_r_matrix.csv'
    ), header=None
)
adjacency_matrix = np.array(matrix)

# %%
# Construim el llistat de coordenades de cada node.
node_coordinates = list()

for i in range(0, 76):
    node_name = dict_data[str(i)]
    filtered_df = df_nodes_coordinates[df_nodes_coordinates['node_name'] == node_name]
    node_coordinates.append([float(filtered_df['x']), float(filtered_df['y']), float(filtered_df['z'])])

# %%
import numpy as np
import matplotlib.pyplot as plt
from nilearn import datasets, plotting
from nilearn.connectome import ConnectivityMeasure

# Visualització en 3D cerebral amb representació dels nodes.
plotting.plot_connectome(
    adjacency_matrix=adjacency_matrix,
    node_coords=node_coordinates,
    node_color='steelblue',
    title='Brain with Nodes',
    display_mode='ortho',
    annotate=True,
)
plt.show()
# Out:
# /home/guillem/.local/lib/python3.6/site-packages/nilearn/__init__.py:69: FutureWarning: Python 3.6 support is deprecated and will be removed in release 0.10 of Nilearn. Consider switching to Python 3.8 or 3.9.
#   _python_deprecation_warnings()
